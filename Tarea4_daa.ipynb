# %% [markdown]
# <a href="https://colab.research.google.com/github/ibzan79/daa_2021_1/blob/master/Tarea4_daa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def ejemplo4(n):
  contador_tareas = 0
  count = 0
  print("Nivel 1") # Para que imprima 3 operaciones puse un print en cada instrucción fuera del while
  contador_tareas += 1
  i = n 
  print("Nivel 1") # Para que imprima 3 operaciones puse un print en cada instrucción fuera del while
  contador_tareas += 1
  while i >= 1:
    count += 1
    i = i // 2
    print("Nivel 2")
    contador_tareas += 1
  basura = 3 + 2
  print("Nivel 1") # Para que imprima 3 operaciones puse un print en cada instrucción fuera del while
  contador_tareas += 1
  print("Total tareas:", contador_tareas)
  return count

print(ejemplo4(2), "\n")
print(ejemplo4(4), "\n")
print(ejemplo4(8), "\n")
print(ejemplo4(10), "\n")
print(ejemplo4(100), "\n")
print(ejemplo4(1000), "\n")
print(ejemplo4(10000), "\n")
print(ejemplo4(100000), "\n")
print(ejemplo4(1000000), "\n")
# Out:
# Nivel 1
# Nivel 1
# Nivel 2
# Nivel 2
# Nivel 1
# Total tareas: 5
# 2
#
# Nivel 1
# Nivel 1
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 1
# Total tareas: 6
# 3
#
# Nivel 1
# Nivel 1
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 1
# Total tareas: 7
# 4
#
# Nivel 1
# Nivel 1
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 1
# Total tareas: 7
# 4
#
# Nivel 1
# Nivel 1
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 1
# Total tareas: 10
# 7
#
# Nivel 1
# Nivel 1
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 1
# Total tareas: 13
# 10
#
# Nivel 1
# Nivel 1
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 1
# Total tareas: 17
# 14
#
# Nivel 1
# Nivel 1
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# Nivel 2
# ...
